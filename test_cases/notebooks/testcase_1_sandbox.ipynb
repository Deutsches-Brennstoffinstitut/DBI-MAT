# %%
import sys
sys.path.append('..\\..\\') # back to main folder
sys.path.append('..\\..\\base\\source\\data') # back to main folder

from base.source.helper.initialize_logger import LoggingLevels
from test_cases.source.systems.Test_1_Basic_Production_H2 import Model_Test_1

# %%
my_system_model = Model_Test_1(database_name='dbi_mat', db_location='local', logging_level=LoggingLevels.CRITICAL)
my_system_model.run()
my_system_model.calculate_costs()
my_results = my_system_model.create_results()

df_basic_econ = my_results.basic_econ_system_settings.to_dataframe()
df_basic_tech = my_results.basic_technical_settings.to_dataframe()
df_branch_info = my_results.branch_information.to_dataframe()
df_tech_results1 = my_results.component_technical_results[0].to_dataframe()
df_tech_results2 = my_results.port_results[0].to_dataframe()
df_econ_1 = my_results.component_economic_results[0].to_dataframe()
df_econ_CAPEX = my_results.component_economic_results[0].to_dataframe_ElementCAPEX()
df_econ_fixedOPEX = my_results.component_economic_results[0].to_dataframe_ElementfixedOPEX()
df_econ_variableOPEX = my_results.component_economic_results[0].to_dataframe_ElementvariableOPEX()
print('done')
# Out:
# done

# %%
df_econ_CAPEX
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_branch_info
# Out:
# branch_id                         B00                         \
# component_id                      C01
# port_id                           P00                    P01
# information
# branch_name                 Stromnetz              Stromnetz
# component_name                    Ely                    Ely
# port_type                    ELECTRIC                  WATER
# stream_type                     power                   mass
# stream_unit                        kW                     kg
# direction       stream_into_component  stream_into_component
#
# branch_id                                                         \
# component_id
# port_id                             P02                      P03
# information
# branch_name                   Stromnetz                Stromnetz
# component_name                      Ely                      Ely
# port_type                      HYDROGEN                   OXYGEN
# stream_type                        mass                     mass
# ...

# %%
port_results_1 = my_results.port_results[1].to_dataframe()
port_results_1['B01','C01','P02']
# Out:
# C:\Users\mpumpa\AppData\Local\Temp\ipykernel_6984\363495347.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   port_results_1['B01','C01','P02']
# stream_type      mass_fraction  pressure  temperature  stream
# timeseries
# 0            {'HYDROGEN': 1.0}       inf          inf   0.188
# 1            {'HYDROGEN': 1.0}       inf          inf   0.188
# 2            {'HYDROGEN': 1.0}       inf          inf   0.188
# 3            {'HYDROGEN': 1.0}       inf          inf   0.188
# 4            {'HYDROGEN': 1.0}       inf          inf   0.188
# ...                        ...       ...          ...     ...
# 8755         {'HYDROGEN': 1.0}       inf          inf   0.188
# 8756         {'HYDROGEN': 1.0}       inf          inf   0.188
# 8757         {'HYDROGEN': 1.0}       inf          inf   0.188
# 8758         {'HYDROGEN': 1.0}       inf          inf   0.188
# 8759         {'HYDROGEN': 1.0}       inf          inf   0.188
#
# [8760 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
Addon = 1
SMALL_SIZE = 18 + Addon
MEDIUM_SIZE = 20 + Addon 
BIGGER_SIZE = 20 + Addon

# import cycler
# colors  = [np.array([68.0, 114.0, 196.0])/255, #blue
#            np.array([192.0, 0.0, 0.0])/255, # red
#            np.array([112.0, 173.0, 71.0])/255, #green
#            np.array([255.0, 192.0, 0.0])/255, # yellow
#            np.array([0.0, 0.0, 0.0])/255] # black
# plt.rcParams['axes.prop_cycle'] = cycler.cycler('color', colors)
plt.rcParams.update({'font.sans-serif':'Arial'})
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

plt.subplots(figsize=(13,7))
plt.plot(port_results_1['B01','C01','P02']['stream'], label='H 2 production')
#lt.plot(storage_filling, label='Speicherinhalt')
##lt.plot(demand_o2_kg,label='Bedarf')
plt.legend(loc = "best")
plt.xlabel('Time [h]')
plt.ylabel('Hydrogen Production [kg]')
plt.minorticks_on()
plt.grid(True, which='major', linewidth=1)
plt.grid(True, which='minor', linewidth=0.5)

plt.tight_layout()
#plt.xlim([4050, 4200])
#plt.ylim([0, 100])

#plt.savefig('..\\output\\graphs\\S4_solver_at_work.png')
#plt.savefig('..\\output\\graphs\\S4_solver_at_work.svg')
plt.show
# Out:
# C:\Users\mpumpa\AppData\Local\Temp\ipykernel_6984\2842299612.py:24: PerformanceWarning: indexing past lexsort depth may impact performance.
#   plt.plot(port_results_1['B01','C01','P02']['stream'], label='H 2 production')
# <function matplotlib.pyplot.show(close=None, block=None)>
